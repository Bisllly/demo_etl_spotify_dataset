# %%
import os
import sys
import json
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from multiprocessing import Pool
from concurrent.futures import ThreadPoolExecutor

src_dir = '../src'
if src_dir not in sys.path:
  sys.path.append(src_dir)

from parallel_process_functions import *
from sequential_process_functions import *

# %% [markdown]
# Sequential processing

# %%
# start_time = time.time()
# # json_files = ['data\mpd.slice.0-999.json', 
# #                 'data\mpd.slice.1000-1999.json', 
# #                 'data\mpd.slice.2000-2999.json'] #for testing
# json_files = get_data()
# df_tracks = flatten_structure_sequential(json_files)
# end_time = time.time()
# print('Sequential Processing Time: ', end_time - start_time)
# df_tracks.head()

# %% [markdown]
# Parallel processing

# %%
# json_files = ['data\mpd.slice.0-999.json', 
#                 'data\mpd.slice.1000-1999.json', 
#                 'data\mpd.slice.2000-2999.json'] #for testing
json_files = get_data()
df_tracks = flatten_structure(json_files)
df_tracks = clean_data(df_tracks)
df_tracks.head(1)

pq.write_table(
  pa.Table.from_pandas(df_tracks),
  'tracks_data.parquet',
  compression='SNAPPY'
)
# Out:
# c:\music_recommendaer\spotify_million_playlist_dataset\notebooks\../src\parallel_process_functions.py:44: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_tracks = pd.concat([pd.read_csv(f) for f in temp_files], ignore_index=True)
# c:\music_recommendaer\spotify_million_playlist_dataset\notebooks\../src\parallel_process_functions.py:44: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_tracks = pd.concat([pd.read_csv(f) for f in temp_files], ignore_index=True)
# c:\music_recommendaer\spotify_million_playlist_dataset\notebooks\../src\parallel_process_functions.py:44: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_tracks = pd.concat([pd.read_csv(f) for f in temp_files], ignore_index=True)
# ...

# %%
df_tracks.head()
# Out:
#    pos        artist_name                             track_uri  \
# 0    0      Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1    1     Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2    2             Beyonc  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3    3  Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4    4             Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
#
#                               artist_uri  \
# 0  spotify:artist:2wIVse2owClT7go1WT98tk
# 1  spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 2  spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 3  spotify:artist:31TPClRtHm23RisEBtV3X7
# 4  spotify:artist:5EvFsr3kj42KNv97ZEnqij
#
#                                 track_name  \
# 0  Lose Control feat. Ciara  Fat Man Scoop
# 1                                    Toxic
# 2                            Crazy In Love
# 3                           Rock Your Body
# 4                             It Wasn't Me
#
#                               album_uri  duration_ms  \
# ...
